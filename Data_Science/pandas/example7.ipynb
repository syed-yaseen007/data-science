# %%
import pandas as pd
import numpy as np

# %%
# Load the Excel file into a DataFrame.
df = pd.read_excel("pandas_practice_dataset.xlsx")

# %%
# Display the first 10 rows.
df.head(10)
# Out:
#    ID     Name   Join Date  Score    Status  Rank         City     Category  \
# 0   1    Julia  2022-02-05     88   Pending     9      Phoenix         Toys
# 1   2      Eva  2023-05-20     78  Inactive     1      Houston     Clothing
# 2   3  Charlie  2020-09-26     64   Pending    12      Chicago        Books
# 3   4    David  2020-08-28     92   Pending     8      Chicago  Electronics
# 4   5   Hannah  2020-01-20     57    Active    11      Phoenix     Clothing
# 5   6  Charlie  2023-03-25     70    Active    19  Los Angeles         Toys
# 6   7      Bob  2020-02-29     88    Active    17  Los Angeles    Furniture
# 7   8      Ian  2021-10-04     68  Inactive     8  Los Angeles    Furniture
# 8   9  Charlie  2021-10-29     72    Active     3     New York  Electronics
# 9  10      Bob  2020-08-03     60   Pending     3      Chicago  Electronics
#
#    Price  Stock
# 0  33070    127
# 1  44315     32
# 2  12788    175
# 3  25442    186
# 4  37257    114
# 5   2427    118
# ...

# %%
# Display the last 5 rows.
df.tail()
# Out:
#      ID     Name   Join Date  Score    Status  Rank      City   Category  \
# 95   96    Grace  2020-09-08     64   Pending    19  New York   Clothing
# 96   97    Alice  2021-01-07     94  Inactive     2   Phoenix  Furniture
# 97   98  Charlie  2023-04-04     50  Inactive    12   Houston       Toys
# 98   99    David  2022-07-24     74  Inactive     6   Chicago   Clothing
# 99  100   Hannah  2022-01-24     56  Inactive     4  New York  Furniture
#
#     Price  Stock
# 95   4087     97
# 96  22499     65
# 97  46314     31
# 98  34086    190
# 99  20980     85

# %%
# Check the number of rows and columns.
df.shape
# Out:
# (100, 10)

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Join Date', 'Score', 'Status', 'Rank', 'City',
#        'Category', 'Price', 'Stock'],
#       dtype='object')

# %%
df["ID"]
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#      ...
# 95     96
# 96     97
# 97     98
# 98     99
# 99    100
# Name: ID, Length: 100, dtype: int64

# %%
df["Name"]
# Out:
# 0       Julia
# 1         Eva
# 2     Charlie
# 3       David
# 4      Hannah
#        ...
# 95      Grace
# 96      Alice
# 97    Charlie
# 98      David
# 99     Hannah
# Name: Name, Length: 100, dtype: object

# %%
df["Join Date"]
# Out:
# 0     2022-02-05
# 1     2023-05-20
# 2     2020-09-26
# 3     2020-08-28
# 4     2020-01-20
#          ...
# 95    2020-09-08
# 96    2021-01-07
# 97    2023-04-04
# 98    2022-07-24
# 99    2022-01-24
# Name: Join Date, Length: 100, dtype: object

# %%
df["Score"]
# Out:
# 0     88
# 1     78
# 2     64
# 3     92
# 4     57
#       ..
# 95    64
# 96    94
# 97    50
# 98    74
# 99    56
# Name: Score, Length: 100, dtype: int64

# %%
df["Status"]
# Out:
# 0      Pending
# 1     Inactive
# 2      Pending
# 3      Pending
# 4       Active
#         ...
# 95     Pending
# 96    Inactive
# 97    Inactive
# 98    Inactive
# 99    Inactive
# Name: Status, Length: 100, dtype: object

# %%
df["Rank"]
# Out:
# 0      9
# 1      1
# 2     12
# 3      8
# 4     11
#       ..
# 95    19
# 96     2
# 97    12
# 98     6
# 99     4
# Name: Rank, Length: 100, dtype: int64

# %%
df["City"]
# Out:
# 0      Phoenix
# 1      Houston
# 2      Chicago
# 3      Chicago
# 4      Phoenix
#         ...
# 95    New York
# 96     Phoenix
# 97     Houston
# 98     Chicago
# 99    New York
# Name: City, Length: 100, dtype: object

# %%
df["Category"]
# Out:
# 0            Toys
# 1        Clothing
# 2           Books
# 3     Electronics
# 4        Clothing
#          ...
# 95       Clothing
# 96      Furniture
# 97           Toys
# 98       Clothing
# 99      Furniture
# Name: Category, Length: 100, dtype: object

# %%
df["Price"]
# Out:
# 0     33070
# 1     44315
# 2     12788
# 3     25442
# 4     37257
#       ...
# 95     4087
# 96    22499
# 97    46314
# 98    34086
# 99    20980
# Name: Price, Length: 100, dtype: int64

# %%
df["Stock"]
# Out:
# 0     127
# 1      32
# 2     175
# 3     186
# 4     114
#      ...
# 95     97
# 96     65
# 97     31
# 98    190
# 99     85
# Name: Stock, Length: 100, dtype: int64

# %%
df.describe()
# Out:
#                ID       Score      Rank         Price       Stock
# count  100.000000  100.000000  100.0000    100.000000  100.000000
# mean    50.500000   74.070000    8.6600  24646.770000   95.080000
# std     29.011492   14.447575    5.4499  15251.683331   59.771227
# min      1.000000   50.000000    1.0000    297.000000    3.000000
# 25%     25.750000   63.000000    4.0000  11829.000000   36.750000
# 50%     50.500000   73.000000    8.0000  23518.500000   97.500000
# 75%     75.250000   88.000000   13.0000  38486.750000  150.250000
# max    100.000000   99.000000   19.0000  49911.000000  196.000000

# %%
df.isnull().sum()
# Out:
# ID           0
# Name         0
# Join Date    0
# Score        0
# Status       0
# Rank         0
# City         0
# Category     0
# Price        0
# Stock        0
# dtype: int64

# %%
df[["Name","City"]]
# Out:
#        Name      City
# 0     Julia   Phoenix
# 1       Eva   Houston
# 2   Charlie   Chicago
# 3     David   Chicago
# 4    Hannah   Phoenix
# ..      ...       ...
# 95    Grace  New York
# 96    Alice   Phoenix
# 97  Charlie   Houston
# 98    David   Chicago
# 99   Hannah  New York
#
# [100 rows x 2 columns]

# %%
df[df["Score"]>90]
df.query("Score>90")
# Out:
#     ID     Name   Join Date  Score    Status  Rank         City     Category  \
# 3    4    David  2020-08-28     92   Pending     8      Chicago  Electronics
# 19  20    Julia  2023-01-20     93   Pending     2      Phoenix         Toys
# 27  28    Frank  2021-06-28     93   Pending     1  Los Angeles        Books
# 29  30      Bob  2021-09-30     98  Inactive     5  Los Angeles        Books
# 31  32      Bob  2020-06-16     91   Pending    14     New York         Toys
# 35  36   Hannah  2023-12-31     96   Pending    14     New York    Furniture
# 36  37  Charlie  2023-06-06     93    Active     7      Phoenix    Furniture
# 47  48   Hannah  2022-02-17     99   Pending     7     New York         Toys
# 53  54    Julia  2021-08-30     96    Active     7      Phoenix        Books
# 55  56   Hannah  2024-02-09     93    Active     2     New York    Furniture
# 57  58      Eva  2021-10-30     96   Pending    13      Chicago     Clothing
# ...

# %%
df[df["City"]=="New York"]
df.query("City =='New York'")
# Out:
#      ID     Name   Join Date  Score    Status  Rank      City     Category  \
# 8     9  Charlie  2021-10-29     72    Active     3  New York  Electronics
# 16   17    Grace  2021-08-04     71  Inactive     9  New York    Furniture
# 18   19      Ian  2020-11-06     73   Pending    12  New York     Clothing
# 24   25    Frank  2020-12-04     82  Inactive    12  New York        Books
# 31   32      Bob  2020-06-16     91   Pending    14  New York         Toys
# 32   33    Julia  2020-04-03     77    Active     3  New York     Clothing
# 35   36   Hannah  2023-12-31     96   Pending    14  New York    Furniture
# 47   48   Hannah  2022-02-17     99   Pending     7  New York         Toys
# 50   51    Julia  2020-04-02     51    Active    11  New York    Furniture
# 55   56   Hannah  2024-02-09     93    Active     2  New York    Furniture
# 62   63    Frank  2023-07-03     99   Pending     7  New York    Furniture
# ...

# %%
df[(df["Score"]>85)&(df["City"]=="Chicago")]
df.query("Score >85 and City=='Chicago'")
# Out:
#     ID   Name   Join Date  Score    Status  Rank     City     Category  Price  \
# 3    4  David  2020-08-28     92   Pending     8  Chicago  Electronics  25442
# 42  43    Eva  2021-10-04     88    Active    19  Chicago    Furniture   8220
# 57  58    Eva  2021-10-30     96   Pending    13  Chicago     Clothing   2149
# 63  64  Julia  2023-03-15     89  Inactive     1  Chicago     Clothing   7258
# 67  68  Grace  2022-01-21     91   Pending     3  Chicago  Electronics  15251
#
#     Stock
# 3     186
# 42     94
# 57    173
# 63    150
# 67    129

# %%
df[(df["Price"]>20000)&(df["Price"]>40000)]
df.query("20000<Price<40000")
# Out:
#      ID     Name   Join Date  Score    Status  Rank         City     Category  \
# 0     1    Julia  2022-02-05     88   Pending     9      Phoenix         Toys
# 3     4    David  2020-08-28     92   Pending     8      Chicago  Electronics
# 4     5   Hannah  2020-01-20     57    Active    11      Phoenix     Clothing
# 9    10      Bob  2020-08-03     60   Pending     3      Chicago  Electronics
# 10   11    Frank  2021-07-28     60  Inactive     1  Los Angeles        Books
# 13   14    Grace  2021-05-04     89  Inactive     7  Los Angeles    Furniture
# 14   15      Ian  2020-05-20     73  Inactive     9  Los Angeles  Electronics
# 15   16    Grace  2022-07-16     52   Pending     7      Chicago        Books
# 17   18    Alice  2021-05-27     51    Active     8      Phoenix         Toys
# 20   21   Hannah  2022-08-09     79  Inactive     1  Los Angeles         Toys
# 25   26    Alice  2023-08-01     61  Inactive     8  Los Angeles     Clothing
# ...

# %%
df[(df["Status"]=="Active")|(df["Status"]=="Pending")]
df.query("Status=='Active'or Status=='Pending'")
# Out:
#     ID     Name   Join Date  Score   Status  Rank         City     Category  \
# 0    1    Julia  2022-02-05     88  Pending     9      Phoenix         Toys
# 2    3  Charlie  2020-09-26     64  Pending    12      Chicago        Books
# 3    4    David  2020-08-28     92  Pending     8      Chicago  Electronics
# 4    5   Hannah  2020-01-20     57   Active    11      Phoenix     Clothing
# 5    6  Charlie  2023-03-25     70   Active    19  Los Angeles         Toys
# ..  ..      ...         ...    ...      ...   ...          ...          ...
# 91  92      Eva  2020-05-18     74  Pending     2     New York  Electronics
# 92  93      Eva  2021-11-15     94  Pending     5      Phoenix  Electronics
# 93  94      Bob  2021-11-07     90  Pending     1      Houston     Clothing
# 94  95    Grace  2021-02-17     78   Active     1      Chicago    Furniture
# 95  96    Grace  2020-09-08     64  Pending    19     New York     Clothing
#
#     Price  Stock
# 0   33070    127
# 2   12788    175
# ...

# %%
df.sort_values("Score",ascending=False)
# Out:
#     ID     Name   Join Date  Score    Status  Rank         City     Category  \
# 62  63    Frank  2023-07-03     99   Pending     7     New York    Furniture
# 47  48   Hannah  2022-02-17     99   Pending     7     New York         Toys
# 29  30      Bob  2021-09-30     98  Inactive     5  Los Angeles        Books
# 78  79      Bob  2020-08-19     97   Pending     9  Los Angeles  Electronics
# 53  54    Julia  2021-08-30     96    Active     7      Phoenix        Books
# ..  ..      ...         ...    ...       ...   ...          ...          ...
# 17  18    Alice  2021-05-27     51    Active     8      Phoenix         Toys
# 22  23      Ian  2022-09-25     51   Pending     5      Chicago  Electronics
# 50  51    Julia  2020-04-02     51    Active    11     New York    Furniture
# 65  66  Charlie  2023-03-16     51    Active    13      Phoenix     Clothing
# 97  98  Charlie  2023-04-04     50  Inactive    12      Houston         Toys
#
#     Price  Stock
# 62  29955     85
# ...

# %%
df.sort_values(["City","Score"])
# Out:
#     ID     Name   Join Date  Score    Status  Rank     City     Category  \
# 22  23      Ian  2022-09-25     51   Pending     5  Chicago  Electronics
# 15  16    Grace  2022-07-16     52   Pending     7  Chicago        Books
# 68  69      Eva  2022-04-23     53  Inactive     7  Chicago         Toys
# 39  40  Charlie  2020-03-30     56  Inactive    15  Chicago  Electronics
# 74  75    David  2021-11-20     59  Inactive    19  Chicago    Furniture
# ..  ..      ...         ...    ...       ...   ...      ...          ...
# 36  37  Charlie  2023-06-06     93    Active     7  Phoenix    Furniture
# 92  93      Eva  2021-11-15     94   Pending     5  Phoenix  Electronics
# 96  97    Alice  2021-01-07     94  Inactive     2  Phoenix    Furniture
# 53  54    Julia  2021-08-30     96    Active     7  Phoenix        Books
# 88  89      Eva  2020-04-02     96    Active    17  Phoenix        Books
#
#     Price  Stock
# 22   2911     60
# 15  27948     20
# 68   1254     16
# 39  37604     92
# ...

# %%
print(df["Score"].mean())
# Out:
# 74.07

# %%
df["Price"].min()
# Out:
# 297

# %%
df['Stock'].min()
# Out:
# 3

# %%
df["Category"].drop_duplicates().copy
# Out:
# <bound method NDFrame.copy of 0           Toys
# 1       Clothing
# 2          Books
# 3    Electronics
# 6      Furniture
# Name: Category, dtype: object>

# %%
df.groupby("Category")["Price"].agg("mean")
# Out:
# Category
# Books          27770.461538
# Clothing       21708.230769
# Electronics    24303.470588
# Furniture      24305.807692
# Toys           27452.055556
# Name: Price, dtype: float64

# %%
df.groupby("City")["Stock"].agg("sum")
# Out:
# City
# Chicago        2049
# Houston        1615
# Los Angeles    1482
# New York       2189
# Phoenix        2173
# Name: Stock, dtype: int64

# %%
df.groupby("Status").count()
# Out:
#           ID  Name  Join Date  Score  Rank  City  Category  Price  Stock
# Status
# Active    36    36         36     36    36    36        36     36     36
# Inactive  35    35         35     35    35    35        35     35     35
# Pending   29    29         29     29    29    29        29     29     29

# %%
df.groupby("City")["Score"].mean()
# Out:
# City
# Chicago        71.904762
# Houston        70.937500
# Los Angeles    77.388889
# New York       76.095238
# Phoenix        73.791667
# Name: Score, dtype: float64

# %%
df.groupby("Category")["Price"].max()
# Out:
# Category
# Books          46860
# Clothing       47125
# Electronics    49911
# Furniture      46943
# Toys           48454
# Name: Price, dtype: int64

# %%
df["Discount_price"] = df["Price"]*0.9

# %%
df["Join Date"] = pd.to_datetime(df["Join Date"])
df["Join_Year"] = df["Join Date"].dt.year

# %%
df["Name"].str.startswith("A").sum()
# Out:
# np.int64(5)

# %%
df.groupby("City")["Price"].mean().round(2)
# Out:
# City
# Chicago        19909.95
# Houston        27150.12
# Los Angeles    24174.06
# New York       23682.48
# Phoenix        28320.88
# Name: Price, dtype: float64
